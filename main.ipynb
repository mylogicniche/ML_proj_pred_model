# %%
import pandas as pd
import numbers
import re
import seaborn as sns
import matplotlib.pyplot as plt
import time
# %matplotlib inline

# %%
re.findall("[0-9]+,[0-9]+", "145,447")
# Out:
# ['145,447']

# %%
df = pd.read_csv("data.csv", delimiter=';')

# %%
df.head()
# Out:
#        Date Feed Composition 1 Feed Composition 2 Effluent composition 1  \
# 0  1-Jan-16             16,140              0,290                  1,150
# 1  2-Jan-16             17,180              0,270                  0,970
# 2  3-Jan-16             18,720              0,220                  0,760
# 3  4-Jan-16             16,380             13,600                  1,580
# 4  5-Jan-16             17,990             18,620                  2,010
#
#   Effluent composition 3 Conversion Feed Flow Inlet Temp    Temp1    Temp2  \
# 0                  1,270     92,875   210,038    135,020  145,447  134,347
# 1                  1,930     94,354   205,164    135,001  145,454  134,707
# 2                  2,980     95,940   149,690    134,366  145,511  135,748
# 3                  2,100     90,354   230,104    135,102  144,896  135,971
# 4                  1,620     88,827   209,876    135,102  145,546  134,370
#
# ...

# %%
df.isnull().sum()
# Out:
# Date                        0
# Feed Composition 1          0
# Feed Composition 2          0
# Effluent composition 1      0
# Effluent composition 3      0
# Conversion                  0
# Feed Flow                   1
# Inlet Temp                  1
# Temp1                       6
# Temp2                       6
# Temp3                      34
# Temp4                       6
# Temp5                       6
# Temp6                       6
# Outlet Temp                 1
# Water in Temp               1
# Water out Temp              1
# Water Flow                  1
# Unnamed: 18               625
# dtype: int64

# %%
df.shape
# Out:
# (627, 19)

# %%
df.drop("Unnamed: 18", axis=1, inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (593, 18)

# %%
df
# Out:
#           Date Feed Composition 1 Feed Composition 2 Effluent composition 1  \
# 33    3-Feb-16             17,190              6,120                   #YOK
# 34    4-Feb-16             17,590              5,970                   #YOK
# 35    5-Feb-16             19,310              1,120                   #YOK
# 36    6-Feb-16             18,400              1,230                   #YOK
# 37    7-Feb-16             17,230              0,980                  1,550
# 38    8-Feb-16             16,820              1,090                  1,020
# 39    9-Feb-16             16,910              0,920                  0,920
# 40   10-Feb-16             16,840              0,640                   #YOK
# 41   11-Feb-16             15,470              0,640                  0,900
# 42   12-Feb-16             14,410              0,670                  1,190
# 43   13-Feb-16             15,060              0,580                  1,440
# ...

# %%
df.dtypes
# Out:
# Date                      object
# Feed Composition 1        object
# Feed Composition 2        object
# Effluent composition 1    object
# Effluent composition 3    object
# Conversion                object
# Feed Flow                 object
# Inlet Temp                object
# Temp1                     object
# Temp2                     object
# Temp3                     object
# Temp4                     object
# Temp5                     object
# Temp6                     object
# Outlet Temp               object
# Water in Temp             object
# Water out Temp            object
# Water Flow                object
# dtype: object

# %%
df_woDate = df.drop("Date", axis=1).applymap(lambda x: float(x.replace(",",".")) if re.findall("[0-9]+,[0-9]+", x) else float('NaN'))

# %%
df_Date = df['Date'].apply(lambda x: datetime.datetime.strptime(x, '%d-%b-%y'))

# %%
df = pd.concat([df_Date, df_woDate], axis=1)
df
# Out:
#           Date  Feed Composition 1  Feed Composition 2  \
# 33  2016-02-03               17.19                6.12
# 34  2016-02-04               17.59                5.97
# 35  2016-02-05               19.31                1.12
# 36  2016-02-06               18.40                1.23
# 37  2016-02-07               17.23                0.98
# 38  2016-02-08               16.82                1.09
# 39  2016-02-09               16.91                0.92
# 40  2016-02-10               16.84                0.64
# 41  2016-02-11               15.47                0.64
# 42  2016-02-12               14.41                0.67
# 43  2016-02-13               15.06                0.58
# 44  2016-02-14               15.09                0.61
# 45  2016-02-15               15.63                0.61
# 46  2016-02-16               15.99                0.50
# 47  2016-02-17               16.56                0.37
# 48  2016-02-18               16.78               11.04
# ...

# %%
df.isnull().sum()
# Out:
# Date                        0
# Feed Composition 1         38
# Feed Composition 2         62
# Effluent composition 1     91
# Effluent composition 3     89
# Conversion                100
# Feed Flow                   0
# Inlet Temp                  0
# Temp1                       0
# Temp2                       0
# Temp3                       0
# Temp4                       0
# Temp5                       0
# Temp6                       0
# Outlet Temp                 0
# Water in Temp               0
# Water out Temp              0
# Water Flow                  0
# dtype: int64

# %%
df.describe()
# Out:
#        Feed Composition 1  Feed Composition 2  Effluent composition 1  \
# count          555.000000          531.000000              502.000000
# mean            19.058577            3.894068                1.827789
# std              5.352387            4.129788                0.708861
# min              0.000000            0.000000                0.000000
# 25%             15.380000            0.325000                1.310000
# 50%             18.510000            3.230000                1.660000
# 75%             22.425000            6.320000                2.310000
# max             44.710000           43.240000                4.450000
#
#        Effluent composition 3  Conversion   Feed Flow  Inlet Temp       Temp1  \
# count              504.000000  493.000000  593.000000  593.000000  593.000000
# mean                 1.848591   89.114304  193.457941  139.168243  155.117946
# std                  0.432394   24.457927   84.041978   22.794357   12.565373
# ...

# %%
plt.figure(figsize=(15, 8))
plt.plot(df['Date'], df["Feed Composition 1"])
plt.plot(df['Date'], df["Feed Composition 2"])

# %% [markdown]
# ### Correlation amoung features

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr())
